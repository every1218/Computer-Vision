# %% [markdown]
# # Hello world !!!

# %% [markdown]
# ## Hello world !!!

# %% [markdown]
# ### Hello word !!!

# %% [markdown]
# print("hello python !!!")

# %%
print("hello python !!!")
# Out:
# hello python !!!
